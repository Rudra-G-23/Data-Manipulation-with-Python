# %%
# check the version
import numpy 
import pandas
import matplotlib

# %%
print(numpy.__version__)
print(pandas.__version__)
print(matplotlib.__version__)
# Out:
# 2.2.5
# 2.2.3
# 3.10.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Colored Scatterplots

# %%
iris = pd.read_csv(r"C:\Users\Rudra\Desktop\Data Manipulation with Python\003_Matplotlib\dataset\datasets-session-24\iris.csv")
iris.sample(5)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 92  93            5.8           2.6            4.0           1.2
# 89  90            5.5           2.5            4.0           1.3
# 35  36            5.0           3.2            1.2           0.2
# 49  50            5.0           3.3            1.4           0.2
# 62  63            6.0           2.2            4.0           1.0
#
#             Species
# 92  Iris-versicolor
# 89  Iris-versicolor
# 35      Iris-setosa
# 49      Iris-setosa
# 62  Iris-versicolor

# %%
iris['Species'] = iris['Species'].replace({
        'Iris-setosa' : 0,
        'Iris-versicolor' : 1,
        'Iris-virginica': 2
})

# %%
iris.sample(3)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 113  114            5.7           2.5            5.0           2.0        2
# 64    65            5.6           2.9            3.6           1.3        1
# 11    12            4.8           3.4            1.6           0.2        0

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
pd.set_option('future.no_silent_downcasting', True)
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 138  139            6.0           3.0            4.8           1.8        2
# 95    96            5.7           3.0            4.2           1.2        1
# 27    28            5.2           3.5            1.5           0.2        0
# 22    23            4.6           3.6            1.0           0.2        0
# 115  116            6.4           3.2            5.3           2.3        2

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# scatter plot of different iris
plt.scatter(iris['PetalLengthCm'], iris['SepalWidthCm'], c=iris['Species'])
plt.xlabel('Petal Length')
plt.ylabel('Sepal Length')
plt.show()

# %%
# camp alpha 
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet',alpha=0.7)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()

# %% [markdown]
# ### Plot size

# %%
plt.figure(figsize=(15,7))

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet',alpha=0.7)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()

# %% [markdown]
# ### Annotations

# %%
batters = pd.read_csv(r"C:\Users\Rudra\Desktop\Data Manipulation with Python\003_Matplotlib\dataset\datasets-session-24\batter.csv")

# %%
batters.shape
# Out:
# (605, 4)

# %%
# taking a subset of the batters data frame
df = batters.head(50).sample(20, random_state=42)

# %%
sample_df = batters.head(100).sample(25,random_state=5)

# %%
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# 69     D Padikkal  1260  28.000000   119.205298
# 94     SO Hetmyer   831  30.777778   144.020797
# 56        PP Shaw  1588  25.206349   143.580470
# 22       PA Patel  2848  22.603175   116.625717
# 39     GJ Maxwell  2320  25.494505   147.676639
# 24        SS Iyer  2780  31.235955   121.132898

# %%
plt.figure(figsize=(12, 10))
plt.scatter(df['avg'], df['strike_rate'], s=df['runs'], c='purple', alpha=0.6)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.scatter(df['avg'], df['strike_rate'], s=df['runs'], c='purple', alpha=0.6)

for i in range(df.shape[0]):
    plt.text(df['avg'].values[i], df['strike_rate'].values[i], df['batter'].values[i], color='black')
plt.show()

# %%
plt.figure(figsize=(18,10))
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])

for i in range(sample_df.shape[0]):
  plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %%
x = [1,2,3,4]
y = [5,6,7,8]

plt.scatter(x,y)
plt.text(1,5,'Point 1')
plt.text(2,6,'Point 2',fontdict={'size':12,'color':'brown'})
plt.text(3,7,'Point 3')
plt.text(4,8,'Point 4')
# Out:
# Text(4, 8, 'Point 4')

# %% [markdown]
# ### Horizontal and Vertical lines

# %%
plt.figure(figsize=(18,10))
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])

plt.axhline(130,color='red')
plt.axhline(140,color='green')
plt.axvline(30,color='red')

for i in range(sample_df.shape[0]):
  plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %%
# figure size and figure
plt.figure(figsize=(10, 10))
plt.scatter(df['avg'], df['strike_rate'], s=df['runs'], c='purple', alpha=0.6)

# draw line
plt.axhline(135, c='red')
plt.axvline(35, c='red')
plt.axhline(155, c='black')

for i in range(df.shape[0]):
    plt.text(df['avg'].values[i], df['strike_rate'].values[i], df['batter'].values[i], color='black')
plt.show()

# %% [markdown]
# ### Subplots

# %%
# A diff way to plot graphs
batters.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
plt.figure(figsize=(15,6))
plt.scatter(batters['avg'],batters['strike_rate'])
plt.title('Something')
plt.xlabel('Avg')
plt.ylabel('Strike Rate')

plt.show()

# %%
fig,ax = plt.subplots(figsize=(15,6))

ax.scatter(batters['avg'],batters['strike_rate'],color='red',marker='+')
ax.set_title('Average run vs strike rate')
ax.set_xlabel('Avg')
ax.set_ylabel('Strike Rate')

fig.show()
# Out:
# C:\Users\Rudra\AppData\Local\Temp\ipykernel_15464\1141213887.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# batter dataset

# %%
fig, ax = plt.subplots(nrows=2,ncols=1,sharex=True,figsize=(10,6))

ax[0].scatter(batters['avg'],batters['strike_rate'],color='red', marker='+', alpha=0.7)
ax[0].set_title('Avg Vs Strike Rate')
ax[0].set_ylabel('Strike Rate')

ax[1].scatter(batters['avg'],batters['runs'],color='purple', marker='+', alpha=0.7)
ax[1].set_title('Avg Vs Runs')
ax[1].set_ylabel('Runs')
ax[1].set_xlabel('Avg')
# Out:
# Text(0.5, 0, 'Avg')

# %%
batters.columns
# Out:
# Index(['batter', 'runs', 'avg', 'strike_rate'], dtype='object')

# %%
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,10))

ax[0,0].scatter(batters['avg'], batters['runs'], marker='+', c='red')
ax[0,1].scatter(batters['avg'],batters['strike_rate'], marker='+', c='purple')

ax[1,0].hist(batters['avg'], color='red')
ax[1,1].hist(batters['runs'], color='purple', log=True)

plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,2,1)
ax1.scatter(batters['avg'],batters['strike_rate'],color='red', marker='+')

ax2 = fig.add_subplot(2,2,2)
ax2.hist(batters['runs'], log=True, color='green')

ax3 = fig.add_subplot(2,2,3)
ax3.hist(batters['avg'], color='brown')

ax4 = fig.add_subplot(224)
ax4.hist(batters['strike_rate'], color='yellow')

plt.show()

# %% [markdown]
# ### 3D Scatter Plots

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 9
#       7 plt.xlabel('Runs')
#       8 plt.ylabel('avg')
# ----> 9 plt.set_zlabel('strike rate')
#      10 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_zlabel'

# %%
fig = plt.figure(figsize=(8, 8))
ax = plt.subplot(projection='3d')

ax.scatter3D(batters['runs'], batters['avg'], batters['strike_rate'], marker='+', c='purple')
ax.set_title('IPL batsman analysis')

ax.set_xlabel('Runs')
ax.set_ylabel('Avg')
ax.set_zlabel('SR')
plt.show()

# %%
batters

fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(batters['runs'],batters['avg'],batters['strike_rate'],marker='+')
ax.set_title('IPL batsman analysis')

ax.set_xlabel('Runs')
ax.set_ylabel('Avg')
ax.set_zlabel('SR')
# Out:
# Text(0.5, 0, 'SR')

# %% [markdown]
# ### 3D Line Plot

# %%
x = [0,1,5,25]
y = [0,10,13,0]
z = [0,13,20,9]

fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(x,y,z,s=[100,100,100,100])
ax.plot3D(x,y,z,color='red')

# %% [markdown]
# ### 3D Surface Plots

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

# %%
xx, yy = np.meshgrid(x,y)

# %%
z = xx**2 + yy**2
z.shape
# Out:
# (100, 100)

# %%
fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')

p = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
z = np.sin(xx) + np.cos(yy)

fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')

p = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
z = np.sin(xx) + np.log(xx)

fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')

p = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)
plt.show()
# Out:
# C:\Users\Rudra\AppData\Local\Temp\ipykernel_9860\4013453109.py:1: RuntimeWarning: invalid value encountered in log
#   z = np.sin(xx) + np.log(xx)

# %%
fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')

p = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# ### Contour Plots

# %%
fig = plt.figure(figsize=(12,8))

ax = plt.subplot()

p = ax.contour(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
fig = plt.figure(figsize=(12,8))

ax = plt.subplot()

p = ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
z = np.sin(xx) + np.cos(yy)

fig = plt.figure(figsize=(12,8))

ax = plt.subplot()

p = ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# ### Heatmap

# %%
delivery = pd.read_csv(r"C:\Users\Rudra\Desktop\Data Manipulation with Python\003_Matplotlib\dataset\datasets-session-24\IPL_Ball_by_Ball_2008_2022.csv")
delivery.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
temp_df = delivery[(delivery['ballnumber'].isin([1,2,3,4,5,6])) & (delivery['batsman_run']==6)]

# %%
grid = temp_df.pivot_table(index='overs',columns='ballnumber',values='batsman_run',aggfunc='count')

# %%
plt.figure(figsize=(20,10))
plt.imshow(grid)
plt.yticks(delivery['overs'].unique(), list(range(1,21)))
plt.xticks(np.arange(0,6), list(range(1,7)))
plt.colorbar()

# %% [markdown]
# ### Pandas Plot()

# %%
# on a series

s = pd.Series([1,2,3,4,5,6,7])
s.plot(kind='pie')
# Out:
# <Axes: >

# %%
# can be used on a dataframe as well

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tips['size'] = tips['size'] * 100

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner   200
# 1       10.34  1.66    Male     No  Sun  Dinner   300
# 2       21.01  3.50    Male     No  Sun  Dinner   300
# 3       23.68  3.31    Male     No  Sun  Dinner   200
# 4       24.59  3.61  Female     No  Sun  Dinner   400

# %%
# Scatter plot -> labels -> markers -> figsize -> color -> cmap
tips.plot(kind='scatter',x='total_bill',y='tip',title='Cost Analysis',marker='+',figsize=(10,6),s='size',c='sex',cmap='viridis')
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='total_bill', ylabel='tip'>

# %%
# 2d plot
# dataset = 'https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv'

stocks = pd.read_csv(r"C:\Users\Rudra\Desktop\Data Manipulation with Python\003_Matplotlib\dataset\datasets-session-24\stock.csv")
stocks.head()
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %%
# default is line chart
stocks['MSFT'].plot()
# Out:
# <Axes: >

# %%
stocks.columns
# Out:
# Index(['Date', 'MSFT', 'FB', 'AAPL'], dtype='object')

# %%
stocks.plot(x='Date')
# Out:
# <Axes: xlabel='Date'>

# %%
stocks[['Date','AAPL','FB']].plot(kind='line',x='Date')
# Out:
# <Axes: xlabel='Date'>

# %%
# bar chart -> single -> horizontal -> multiple
# using tips
temp = pd.read_csv(r"C:\Users\Rudra\Desktop\Data Manipulation with Python\003_Matplotlib\dataset\datasets-session-24\batsman_season_record.csv")
temp.head()
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
tips.groupby('sex', observed=True)['total_bill'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
temp.columns
# Out:
# Index(['batsman', '2015', '2016', '2017'], dtype='object')

# %%
temp['2015'].plot(kind='bar')
# Out:
# <Axes: >

# %%
temp.plot(kind='bar')
# Out:
# <Axes: >

# %%
# stacked bar chart
temp.plot(kind='bar',stacked=True)
# Out:
# <Axes: >

# %%
# histogram
# using stocks

stocks[['MSFT','FB']].plot(kind='hist',bins=40)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# pie -> single and multiple
df = pd.DataFrame(
    {
        'batsman':['Dhawan','Rohit','Kohli','SKY','Pandya','Pant'],
        'match1':[120,90,35,45,12,10],
        'match2':[0,1,123,130,34,45],
        'match3':[50,24,145,45,10,90]
    }
)

df.head()
# Out:
#   batsman  match1  match2  match3
# 0  Dhawan     120       0      50
# 1   Rohit      90       1      24
# 2   Kohli      35     123     145
# 3     SKY      45     130      45
# 4  Pandya      12      34      10

# %%
df['match1'].plot(kind='pie', autopct='%0.1f%%', labels=df['batsman'], title='Matches with batsman')
# Out:
# <Axes: title={'center': 'Matches with batsman'}, ylabel='match1'>

# %%
# multiple pie charts
df[['match1','match2','match3']].plot(kind='pie',subplots=True,figsize=(15,10), labels=df['batsman'], title='All matches with Batsman')
# Out:
# array([<Axes: ylabel='match1'>, <Axes: ylabel='match2'>,
#        <Axes: ylabel='match3'>], dtype=object)

# %%
# multiple separate graphs together
# using stocks

stocks.plot(kind='line',subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
# on multiindex dataframes
# using tips

# %%
tips.pivot_table(
    index=['day','time'],
    columns=['sex','smoker'],
    values='total_bill',
    aggfunc='mean',
    observed=True,
).plot(kind='pie',subplots=True,figsize=(20,10))

plt.title("tips all details")
plt.show()
